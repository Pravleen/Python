# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]

# %%
plt.hist(x)
plt.show()

# %%
plt.hist(x,bins=3)
plt.show()

# %%
x=np.random.uniform(0,5,250)

# %%
plt.hist(x,100)
plt.show()

# %%
x=np.random.normal(5.0,1.0,10000) #mean=5.0 ,std=1

# %%
plt.hist(x,100)
plt.show()

# %%
x=[1,2,3,4,5]
y=[2,4,6,8,10]

# %%
plt.scatter(x,y)

# %%
x=np.random.randint(1,100,20)
y=np.random.randint(1,100,20)
plt.scatter(x,y)
plt.title("SCATTER PLOT")
plt.xlabel("X-AXIS")
plt.ylabel("Y-AXIS")
plt.show()
